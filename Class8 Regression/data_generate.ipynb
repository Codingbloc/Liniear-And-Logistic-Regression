# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline
from sklearn.datasets import make_regression

# %%
X, y = make_regression(n_samples=500, n_features=1, noise=1.91)
print X.min(), X.max(), y.min(), y.max()
print X.shape,y.shape
# Out:
# -2.7761807164439185 3.101326701000943 -159.26049953863583 172.9683933819861
# (500, 1) (500,)

# %%
plt.scatter(X[:, 0], y[:])

# %%
print X.shape
#X=X**3
#print X.shape #Note range is not changed
# Out:
# (500, 1)

# %% [markdown]
# # Note for graph y=x(cube) the following graph is not the graph of y=x(cube)

# %%
plt.scatter(X**3, y)

# %% [markdown]
# # This is the graph of y=x(cube) if we draw (x,x**3) second point means y-axis point

# %%
plt.scatter(X,X**3)

# %%
Y = X**3 + X**2
plt.scatter(X**2,Y)

# %%
def f(x): #function with name f
    return 5*x**5 + 4*x**2 - 3.0 + 50*(2*np.random.random()-1)

# %%
k1 = np.asarray([f(x) for x in range(-100, 100)])
print k1.shape

k2 = np.asarray([f(x) for x in range(-100, 100)])
# Out:
# (200,)

# %%
plt.scatter(range(-100, 100), k1)

plt.scatter(range(-100, 100), k2)
